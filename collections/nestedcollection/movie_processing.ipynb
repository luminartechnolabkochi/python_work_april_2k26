# %%
movies = [
    {"title": "ABCD", "language": "Malayalam", "rating": 9, "year": 2011, "runtime": 120},
    {"title": "Vazha", "language": "Malayalam", "rating": 9, "year": 2022, "runtime": 140},
    {"title": "Kumbalangi Nights", "language": "Malayalam", "rating": 9, "year": 2019, "runtime": 135},
    {"title": "Super Deluxe", "language": "Tamil", "rating": 9, "year": 2019, "runtime": 176},
    {"title": "Jai Bhim", "language": "Tamil", "rating": 9, "year": 2021, "runtime": 164},
    {"title": "Parasite", "language": "Korean", "rating": 10, "year": 2019, "runtime": 132},
    {"title": "Spirited Away", "language": "Japanese", "rating": 10, "year": 2001, "runtime": 125},
    {"title": "The Godfather", "language": "English", "rating": 10, "year": 1972, "runtime": 175},
    {"title": "Inception", "language": "English", "rating": 9, "year": 2010, "runtime": 148},
    {"title": "Tumbbad", "language": "Hindi", "rating": 9, "year": 2018, "runtime": 104},
    {"title": "Dangal", "language": "Hindi", "rating": 9, "year": 2016, "runtime": 161},
    {"title": "Kantara", "language": "Kannada", "rating": 9, "year": 2022, "runtime": 148},
    {"title": "RRR", "language": "Telugu", "rating": 9, "year": 2022, "runtime": 187},
    {"title": "City of God", "language": "Portuguese", "rating": 10, "year": 2002, "runtime": 130},
    {"title": "Anatomy of a Fall", "language": "French", "rating": 9, "year": 2023, "runtime": 151}
]

# %% [markdown]
# ### Movie with highest runtime

# %%
all_runtime = {m["runtime"] for m in movies }

max_runtime = max(all_runtime)

max_runtime_movie = [m["title"] for m in movies if m["runtime"]==max_runtime]

print("movie with max runtime:",max_runtime_movie)
# Out:
# movie with max runtime: ['RRR']

# %% [markdown]
# ### malayalam movies

# %%
malayalam_movies = [m["title"] for m in movies if m["language"]=="Malayalam"]

print(malayalam_movies)
# Out:
# ['ABCD', 'Vazha', 'Kumbalangi Nights']

# %%
words=["hello","hai","hello","hai"]

wc={w:words.count(w) for w in words}
wc
# Out:
# {'hello': 2, 'hai': 2}

# %%
years= [m["year"] for m in movies]

year_count = {y:years.count(y) for y in years}

print(year_count)
# Out:
# {2011: 1, 2022: 3, 2019: 3, 2021: 1, 2001: 1, 1972: 1, 2010: 1, 2018: 1, 2016: 1, 2002: 1, 2023: 1}

# %%
! pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\luminar\appdata\local\programs\python\python314\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\luminar\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\luminar\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\luminar\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\luminar\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\luminar\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (2.4.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\luminar\appdata\roaming\python\python314\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\luminar\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\luminar\appdata\local\programs\python\python314\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\luminar\appdata\roaming\python\python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\luminar\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
rating=[m["rating"] for m in movies]

runtime = [m["runtime"] for m in movies ]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
plt.scatter(runtime,rating)
plt.show()
